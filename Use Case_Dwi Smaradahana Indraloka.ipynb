# %% [markdown]
# # USE CASE
#
# ## ANSWERED BY DWI SMARADAHANA INDRALOKA
# ***

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Upload CSV Dataset

# %%
a_s = pd.read_csv("automobile-spec.csv")
a_r = pd.read_csv("automobile-risk.csv")
a_l = pd.read_csv("automobile-losses.csv")

# %%
a_s.head()
# Out:
#    ID         make fuel-type aspiration num-of-doors   body-style drive-wheel  \
# 0   1  alfa-romero       gas        std          two  convertible         rwd
# 1   2  alfa-romero       gas        std          two  convertible         rwd
# 2   3  alfa-romero       gas        std          two    hatchback         rwd
# 3   4         audi       gas        std         four        sedan         fwd
# 4   5         audi       gas        std         four        sedan         4wd
#
#   engine-loc  wheel-base  length   ...     engine-size  fuel-system  bore  \
# 0      front        88.6   168.8   ...             130         mpfi  3.47
# 1      front        88.6   168.8   ...             130         mpfi  3.47
# 2      front        94.5   171.2   ...             152         mpfi  2.68
# 3      front        99.8   176.6   ...             109         mpfi  3.19
# 4      front        99.4   176.6   ...             136         mpfi  3.19
#
# ...

# %%
a_r.head()
# Out:
#    ID  symboling
# 0   1          3
# 1   2          3
# 2   3          1
# 3   4          2
# 4   5          2

# %%
a_l.head()
# Out:
#    ID  normalized-losses
# 0   1                NaN
# 1   2                NaN
# 2   3                NaN
# 3   4              164.0
# 4   5              164.0

# %% [markdown]
# ***

# %% [markdown]
# ## Part 1

# %% [markdown]
# ## 1. Join 3 tables using ID as key
# * First we join automobile-spec table and automobile-risk table using outer method based on ID and give name Data1
# * Second we join Data1 table and automobile-losses table using outer method based on ID and give name Data

# %%
data1 = pd.merge(a_s, a_r, how = "outer", on = "ID")
data1.head()
# Out:
#    ID         make fuel-type aspiration num-of-doors   body-style drive-wheel  \
# 0   1  alfa-romero       gas        std          two  convertible         rwd
# 1   2  alfa-romero       gas        std          two  convertible         rwd
# 2   3  alfa-romero       gas        std          two    hatchback         rwd
# 3   4         audi       gas        std         four        sedan         fwd
# 4   5         audi       gas        std         four        sedan         4wd
#
#   engine-loc  wheel-base  length    ...      fuel-system  bore  stroke  \
# 0      front        88.6   168.8    ...             mpfi  3.47    2.68
# 1      front        88.6   168.8    ...             mpfi  3.47    2.68
# 2      front        94.5   171.2    ...             mpfi  2.68    3.47
# 3      front        99.8   176.6    ...             mpfi  3.19    3.40
# 4      front        99.4   176.6    ...             mpfi  3.19    3.40
#
# ...

# %%
data = pd.merge(data1, a_l, how = "outer", on = "ID")
data.head()
# Out:
#    ID         make fuel-type aspiration num-of-doors   body-style drive-wheel  \
# 0   1  alfa-romero       gas        std          two  convertible         rwd
# 1   2  alfa-romero       gas        std          two  convertible         rwd
# 2   3  alfa-romero       gas        std          two    hatchback         rwd
# 3   4         audi       gas        std         four        sedan         fwd
# 4   5         audi       gas        std         four        sedan         4wd
#
#   engine-loc  wheel-base  length        ...          bore  stroke  \
# 0      front        88.6   168.8        ...          3.47    2.68
# 1      front        88.6   168.8        ...          3.47    2.68
# 2      front        94.5   171.2        ...          2.68    3.47
# 3      front        99.8   176.6        ...          3.19    3.40
# 4      front        99.4   176.6        ...          3.19    3.40
#
#    compression-ratio horsepower peak-rpm  city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# ## 2. Quick-look (dimension, data type, head/tail, summary statistics)

# %% [markdown]
# ### a. Dimension

# %%
data.shape
# Out:
# (205, 27)

# %% [markdown]
# ### b. Data Type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 27 columns):
# ID                   205 non-null int64
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         204 non-null object
# body-style           205 non-null object
# drive-wheel          205 non-null object
# engine-loc           205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# cylinder             205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 201 non-null float64
# stroke               201 non-null float64
# compression-ratio    205 non-null float64
# ...

# %% [markdown]
# ### c. Data Head/Tail

# %%
data.head()
# Out:
#    ID         make fuel-type aspiration num-of-doors   body-style drive-wheel  \
# 0   1  alfa-romero       gas        std          two  convertible         rwd
# 1   2  alfa-romero       gas        std          two  convertible         rwd
# 2   3  alfa-romero       gas        std          two    hatchback         rwd
# 3   4         audi       gas        std         four        sedan         fwd
# 4   5         audi       gas        std         four        sedan         4wd
#
#   engine-loc  wheel-base  length        ...          bore  stroke  \
# 0      front        88.6   168.8        ...          3.47    2.68
# 1      front        88.6   168.8        ...          3.47    2.68
# 2      front        94.5   171.2        ...          2.68    3.47
# 3      front        99.8   176.6        ...          3.19    3.40
# 4      front        99.4   176.6        ...          3.19    3.40
#
#    compression-ratio horsepower peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
data.tail()
# Out:
#       ID   make fuel-type aspiration num-of-doors body-style drive-wheel  \
# 200  201  volvo       gas        std         four      sedan         rwd
# 201  202  volvo       gas      turbo         four      sedan         rwd
# 202  203  volvo       gas        std         four      sedan         rwd
# 203  204  volvo    diesel      turbo         four      sedan         rwd
# 204  205  volvo       gas      turbo         four      sedan         rwd
#
#     engine-loc  wheel-base  length        ...          bore  stroke  \
# 200      front       109.1   188.8        ...          3.78    3.15
# 201      front       109.1   188.8        ...          3.78    3.15
# 202      front       109.1   188.8        ...          3.58    2.87
# 203      front       109.1   188.8        ...          3.01    3.40
# 204      front       109.1   188.8        ...          3.78    3.15
#
#      compression-ratio horsepower peak-rpm  city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# ### d. Summary Statistics

# %%
data.describe()
# Out:
#                ID  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000   98.756585  174.049268   65.907805   53.724878
# std     59.322565    6.021776   12.337289    2.145204    2.443522
# min      1.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size        bore      stroke  compression-ratio  \
# count   205.000000   205.000000  201.000000  201.000000         205.000000
# mean   2555.565854   126.907317    3.329751    3.255423          10.142537
# std     520.680204    41.642693    0.273539    0.316717           3.972040
# ...

# %% [markdown]
# ## 3. Identify missing value. If any, how will you handle it?
# * For numerical data we fill the missing value using the mean of the data
# * For categorical data we fill the missing value using the mode of the data

# %%
data.isna().sum()
# Out:
# ID                    0
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          1
# body-style            0
# drive-wheel           0
# engine-loc            0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# cylinder              0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# symboling             0
# normalized-losses    41
# dtype: int64

# %%
data["num-of-doors"].fillna(data["num-of-doors"].mode()[0], inplace = True)

# %%
mean1 = data["bore"].mean()
data["bore"].fillna(mean1, inplace = True)

# %%
mean2 = data["stroke"].mean()
data["stroke"].fillna(mean2, inplace = True)

# %%
data["horsepower"].fillna(data["horsepower"].mode()[0], inplace = True)

# %%
data["peak-rpm"].fillna(data["peak-rpm"].mode()[0], inplace = True)

# %%
mean4 = data["price"].mean()
data["price"].fillna(mean4, inplace = True)

# %%
data["normalized-losses"].fillna(data["normalized-losses"].mode()[0], inplace = True)

# %% [markdown]
# * Rechecking the missing value

# %%
data.isna().sum()
# Out:
# ID                   0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheel          0
# engine-loc           0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# cylinder             0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# symboling            0
# normalized-losses    0
# dtype: int64

# %% [markdown]
# ## 4. Perform visualization using at least 5 difference visualization technique

# %% [markdown]
# ### a. Scatter Plot
# * Engine Size VS Price
# * Horse Power VS Price

# %%
plt.scatter(data["engine-size"],data["price"])
plt.title("Engine Size vs Price")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.show()

plt.scatter(data["horsepower"],data["price"])
plt.title("Horse Power vs Price")
plt.xlabel("Horse Power")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ### b. Cross Table
# * Car Brand VS Body Style
# * Car Brand VS Cylinder

# %%
table = pd.crosstab(data["make"], data["body-style"])
table.div(table.sum(1).astype(float), axis = 0).plot(kind="bar", stacked = True)

table = pd.crosstab(data["make"], data["cylinder"])
table.div(table.sum(1).astype(float), axis = 0).plot(kind="bar", stacked = True)

# %% [markdown]
# ### c. Bar Plot
# * Number of Cars Based on Body Style
# * Number of Cars Based on Engine Type

# %%
plt.hist(data["body-style"], bins = 9, rwidth = 0.9)
plt.title("Number of Cars Based on Body Style")
plt.xlabel("Body Style")
plt.ylabel("Number")
plt.show()

plt.hist(data["engine-type"], bins = 7, rwidth = 0.9)
plt.title("Number of Cars Based on Engine Type")
plt.xlabel("Engine Type")
plt.ylabel("Number")
plt.show()

# %% [markdown]
# ### d. Box Plot
# * Horse Power Distribution Data Based on Car Brand

# %%
plt.figure(figsize = (15,8))
sns.set(style="whitegrid")
sns.boxplot(x = data["make"], y = data["horsepower"])
plt.xticks(rotation=45)
plt.title("Horse Power Distribution Data Based on Car Brand")
# Out:
# Text(0.5,1,'Horse Power Distribution Data Based on Car Brand')

# %% [markdown]
# ### e. Bar Chart
# * 5 Highest Price of Car Brand with Two Doors, Gas Fuel Type and Four Cylinder
# * 5 Lowest Price of Car Brand with Two Doors, Gas Fuel Type and Four Cylinder

# %%
data_new = data[data["num-of-doors"]=="two"]
data_new1 = data_new[data_new["fuel-type"]=="gas"]
data_new2 = data_new1[data_new1["cylinder"]=="four"]
top_5_price = data_new2.sort_values("price", ascending = False).head(5)

top_5_price

x=range(5)
plt.bar(x,top_5_price["price"])
plt.xticks(x,top_5_price["make"])
plt.xlabel("Car Brand")
plt.ylabel("Price")
plt.title("5 Highest Price of Car Brand with Two Doors, Gas Fuel Type and Four Cylinder")
plt.show()

data_new = data[data["num-of-doors"]=="two"]
data_new1 = data_new[data_new["fuel-type"]=="gas"]
data_new2 = data_new1[data_new1["cylinder"]=="four"]
top_5_price = data_new2.sort_values("price").head(5)
top_5_price

x=range(5)
plt.bar(x,top_5_price["price"])
plt.xticks(x,top_5_price["make"])
plt.xlabel("Car Brand")
plt.ylabel("Price")
plt.title("5 Lowest Price of Car Brand with Two Doors, Gas Fuel Type and Four Cylinder")
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Part 2

# %% [markdown]
# ## 1. Car brand with highest price
# * Car Brand with highest price is Mercedes-Benz with Price 45400.0

# %%
car_brand = data.sort_values("price", ascending = False)
car_brand[["make", "price"]].head(1)
# Out:
#              make    price
# 74  mercedes-benz  45400.0

# %% [markdown]
# ## 2. Maximum horsepower for car with 6 cylinder engine
# * Maximum horse power for car with 6 cylinder engine is 207.0 horse power

# %%
data_engine = data[data.cylinder == "six"]
horse_power = data_engine["horsepower"].max()
horse_power
# Out:
# 207.0

# %% [markdown]
# ## 3. Average peak-rpm for ‘turbo’ style aspiration car
#    * Average peak-rpm for ‘turbo’ style aspiration car is 4939.19

# %%
aspiration_style = data[data.aspiration == "turbo"]
peak_rpm = aspiration_style["peak-rpm"].mean()
print(peak_rpm)
# Out:
# 4939.189189189189

# %% [markdown]
# ## 4. Average price based on body-style
# * Convertible body style price is 21890.50
# * Hardtop body style price is 22208.50
# * Hatchback body style price is 10050.29
# * Sedan body style price is 14433.66
# * Wagon body style price is 12371.96

# %%
body_style = data.groupby("body-style")
price_average = body_style["price"].mean()
price_average.head()
# Out:
# body-style
# convertible    21890.500000
# hardtop        22208.500000
# hatchback      10050.289410
# sedan          14433.658945
# wagon          12371.960000
# Name: price, dtype: float64

# %% [markdown]
# ## 5. Average price based on body-style only for Honda car (make=Honda)
# * Hatchback body style price is 7054.43
# * Sedan body style price is 9945.00
# * Wagon body style price is 7295.00

# %%
car_make = data[data.make == "honda"]
body_style = car_make.groupby("body-style")
price_average = body_style["price"].mean()
price_average.head()
# Out:
# body-style
# hatchback    7054.428571
# sedan        9945.000000
# wagon        7295.000000
# Name: price, dtype: float64
